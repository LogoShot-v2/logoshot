# %%
import pandas as pd

# %%
db36 = pd.read_csv("data//output36.csv")
db25 = pd.read_csv("data//output25.csv")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
db25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602355 entries, 0 to 602354
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   doc                                          602355 non-null  object
#  1   CaseNo                                       602355 non-null  int64
#  2   RegisterNo                                   602355 non-null  int64
#  3   Trademark_Name                               602355 non-null  object
#  4   Trademark_Design                             602355 non-null  object
#  5   Filing_Date                                  602355 non-null  object
#  6   Censor                                       602355 non-null  object
#  7   Priority_Date                                26138 non-null   object
#  8   SDate                                        602355 non-null  object
# ...

# %%
db25[db25['RegisterNo']==2113867]
# Out:
#                             doc     CaseNo  RegisterNo  \
# 589520  TrademarkRegXMLB_048001  109033118     2113867
#
#                            Trademark_Name Trademark_Design Filing_Date Censor  \
# 589520  A設計字 ARISE & SHINE台北基督徒 A & S 禮拜堂         (彩色)(平面)   109.05.22    洪梅玲
#
#        Priority_Date      SDate      EDate  ... RegContentAgent/BChinese  \
# 589520           NaN  110.01.01  119.12.31  ...                  ['林怡芳']
#
#         RegContentClassification/Enforcement_Rules  \
# 589520                             ['商標法施行細則第19條']
#
#         RegContentClassification/Class  \
# 589520                      ['\u3000']
#
#        RegContentClassification/Goods_Denomination  RegContentOwner/AChinese  \
# 589520                 ['表彰「社團法人臺北市興起發光協會」會員之會籍。']         ['社團法人臺北市興起發光協會']
#
#        RegContentOwner/AEnglish RegContentOwner/Address  \
# 589520                   [None]                 ['臺北市']
#
#                          RegContentPicture/FileName  \
# ...

# %%
db36
# Out:
#                            doc  Page_Num  Page_Chnum     CaseNo  RegisterNo  \
# 0      TrademarkRegXMLB_038017     101.0       101.0   99029606     1469710
# 1      TrademarkRegXMLB_038017     101.0       101.0   99041187     1469711
# 2      TrademarkRegXMLB_038017     102.0       102.0   99041464     1469712
# 3      TrademarkRegXMLB_038017     102.0       102.0   99043079     1469713
# 4      TrademarkRegXMLB_038017     103.0       103.0   99043798     1469714
# ...                        ...       ...         ...        ...         ...
# 54099  TrademarkRegXMLB_039012       NaN         NaN  101880110     1523920
# 54100  TrademarkRegXMLB_039012       NaN         NaN  101880112     1523921
# 54101  TrademarkRegXMLB_039012       NaN         NaN  101880119     1523922
# 54102  TrademarkRegXMLB_039012       NaN         NaN  101880123     1523923
# 54103  TrademarkRegXMLB_039012       NaN         NaN  101880129     1523924
#
# ...

# %%
set(db25['doc'])
# Out:
# {'TrademarkRegXMLB_039013',
#  'TrademarkRegXMLB_039014',
#  'TrademarkRegXMLB_039015',
#  'TrademarkRegXMLB_039016',
#  'TrademarkRegXMLB_039017',
#  'TrademarkRegXMLB_039018',
#  'TrademarkRegXMLB_039019',
#  'TrademarkRegXMLB_039020',
#  'TrademarkRegXMLB_039021',
#  'TrademarkRegXMLB_039022',
#  'TrademarkRegXMLB_039023',
#  'TrademarkRegXMLB_039024',
#  'TrademarkRegXMLB_040001',
#  'TrademarkRegXMLB_040002',
#  'TrademarkRegXMLB_040003',
#  'TrademarkRegXMLB_040004',
#  'TrademarkRegXMLB_040005',
#  'TrademarkRegXMLB_040006',
#  'TrademarkRegXMLB_040007',
#  'TrademarkRegXMLB_040008',
#  'TrademarkRegXMLB_040009',
#  'TrademarkRegXMLB_040010',
#  'TrademarkRegXMLB_040011',
#  'TrademarkRegXMLB_040012',
#  'TrademarkRegXMLB_040013',
#  'TrademarkRegXMLB_040014',
#  'TrademarkRegXMLB_040015',
#  'TrademarkRegXMLB_040016',
#  'TrademarkRegXMLB_040017',
#  'TrademarkRegXMLB_040018',
#  'TrademarkRegXMLB_040019',
#  'TrademarkRegXMLB_040020',
#  'TrademarkRegXMLB_040021',
# ...

# %%
db25[db25['doc']=='TrademarkRegXMLB_048001']
# Out:
#                             doc     CaseNo  RegisterNo  \
# 585827  TrademarkRegXMLB_048001  108080443     2110174
# 585828  TrademarkRegXMLB_048001  109000805     2110175
# 585829  TrademarkRegXMLB_048001  109000809     2110176
# 585830  TrademarkRegXMLB_048001  109024245     2110177
# 585831  TrademarkRegXMLB_048001  109024249     2110178
# ...                         ...        ...         ...
# 589518  TrademarkRegXMLB_048001  108072139     2113865
# 589519  TrademarkRegXMLB_048001  108072140     2113866
# 589520  TrademarkRegXMLB_048001  109033118     2113867
# 589521  TrademarkRegXMLB_048001  109042128     2113868
# 589522  TrademarkRegXMLB_048001  109055368     2113869
#
#                                            Trademark_Name Trademark_Design  \
# 585827                                         ElderCraft         (墨色)(平面)
# 585828                                          KANTO.PPC         (彩色)(平面)
# 585829                                        KANTO.PPC及圖         (彩色)(平面)
# ...
