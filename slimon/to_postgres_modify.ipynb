# %%
import pandas as pd

# %%
df = pd.read_csv('modify.csv', encoding='utf-8')
# Out:
# c:\users\slimon110\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,7,8,9,11,13,20,28,29,30,32,33,34,41,42,44,49,54,59,64,65,66,67,68,69,71,72,73,75,76,77,79,80,81,82,85,87,88,89,90,91,92,93,94,95,96,98,99,101,102,103,105,107,108,109,111,112,113,114,115,116,117,118,119,120,121,122,123,124) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
cols = list(df.columns)
cols = list(map( lambda x: x.replace('#', '___'),cols))
cols

# %%
df.rename(columns=dict(zip(df.columns, cols)), inplace=True)

# %%
df.to_csv('modify1.csv', encoding='utf-8', sep=';', index=False)

# %%
# Out:
#                             doc    mod_type  Page_Num  Page_Chnum RegisterNo  \
# 0       TrademarkModXMLB_038017  Alteration    2065.0      2065.0   00073426
# 1       TrademarkModXMLB_038017  Alteration    2065.0      2065.0   00090243
# 2       TrademarkModXMLB_038017  Alteration    2065.0      2065.0   00094581
# 3       TrademarkModXMLB_038017  Alteration    2065.0      2065.0   00096441
# 4       TrademarkModXMLB_038017  Alteration    2065.0      2065.0   00122778
# ...                         ...         ...       ...         ...        ...
# 720250  TrademarkModXMLB_048006  Revocation       NaN         NaN   02099743
# 720251  TrademarkModXMLB_048006  Revocation       NaN         NaN   02112403
# 720252  TrademarkModXMLB_048006  SubLicense       NaN         NaN   00990203
# 720253  TrademarkModXMLB_048006  SubLicense       NaN         NaN   01066413
# 720254  TrademarkModXMLB_048006  SubLicense       NaN         NaN   01446877
#
# ...

# %%
|
